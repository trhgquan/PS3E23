# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from sklearn.model_selection import KFold, cross_validate, GridSearchCV
from sklearn.preprocessing import FunctionTransformer, PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
# from xgboost import XGBClassifier
from sklearn.metrics import make_scorer, roc_auc_score, log_loss


import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## References:
# - [Ensemble Modeling with Sklearn Pipelines](https://www.kaggle.com/code/bbusath5/ensemble-modeling-with-sklearn-pipelines)
# - [PSS3E23 EDA which makes sense ⭐️⭐️⭐️⭐️⭐️](https://www.kaggle.com/code/ambrosm/pss3e23-eda-which-makes-sense)

# %% [markdown]
# ## Loading data & first inspect

# %% [markdown]
# Load data

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.describe()
# Out:
#                   id            loc           v(g)          ev(g)  \
# count  101763.000000  101763.000000  101763.000000  101763.000000
# mean    50881.000000      37.347160       5.492684       2.845022
# std     29376.592059      54.600401       7.900855       4.631262
# min         0.000000       1.000000       1.000000       1.000000
# 25%     25440.500000      13.000000       2.000000       1.000000
# 50%     50881.000000      22.000000       3.000000       1.000000
# 75%     76321.500000      42.000000       6.000000       3.000000
# max    101762.000000    3442.000000     404.000000     165.000000
#
#                iv(g)              n              v              l  \
# count  101763.000000  101763.000000  101763.000000  101763.000000
# mean        3.498826      96.655995     538.280956       0.111634
# std         5.534541     171.147191    1270.791601       0.100096
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000      25.000000      97.670000       0.050000
# 50%         2.000000      51.000000     232.790000       0.090000
# 75%         4.000000     111.000000     560.250000       0.150000
# max       402.000000    8441.000000   80843.080000       1.000000
#
#                    d              i  ...              t         lOCode  \
# count  101763.000000  101763.000000  ...  101763.000000  101763.000000
# mean       13.681881      27.573007  ...    1141.357982      22.802453
# std        14.121306      22.856742  ...    9862.795472      38.541010
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         5.600000      15.560000  ...      31.380000       7.000000
# 50%         9.820000      23.360000  ...     125.400000      14.000000
# 75%        18.000000      34.340000  ...     565.920000      26.000000
# max       418.200000     569.780000  ...  935923.390000    2824.000000
#
#            lOComment        lOBlank  locCodeAndComment        uniq_Op  \
# count  101763.000000  101763.000000      101763.000000  101763.000000
# mean        1.773945       3.979865           0.196604      11.896131
# std         5.902412       6.382358           0.998906       6.749549
# min         0.000000       0.000000           0.000000       0.000000
# 25%         0.000000       1.000000           0.000000       8.000000
# 50%         0.000000       2.000000           0.000000      11.000000
# 75%         1.000000       5.000000           0.000000      16.000000
# max       344.000000     219.000000          43.000000     410.000000
#
#            uniq_Opnd       total_Op     total_Opnd    branchCount
# count  101763.000000  101763.000000  101763.000000  101763.000000
# mean       15.596671      57.628116      39.249698       9.839549
# std        18.064261     104.537660      71.692309      14.412769
# min         0.000000       0.000000       0.000000       1.000000
# 25%         7.000000      15.000000      10.000000       3.000000
# 50%        12.000000      30.000000      20.000000       5.000000
# 75%        20.000000      66.000000      45.000000      11.000000
# max      1026.000000    5420.000000    3021.000000     503.000000
#
# [8 rows x 22 columns]

# %%
train.head()
# Out:
#    id   loc  v(g)  ev(g)  iv(g)     n       v     l      d      i  ...  \
# 0   0  22.0   3.0    1.0    2.0  60.0  278.63  0.06  19.56  14.25  ...
# 1   1  14.0   2.0    1.0    2.0  32.0  151.27  0.14   7.00  21.11  ...
# 2   2  11.0   2.0    1.0    2.0  45.0  197.65  0.11   8.05  22.76  ...
# 3   3   8.0   1.0    1.0    1.0  23.0   94.01  0.19   5.25  17.86  ...
# 4   4  11.0   2.0    1.0    2.0  17.0   60.94  0.18   5.63  12.44  ...
#
#    lOCode  lOComment  lOBlank  locCodeAndComment  uniq_Op  uniq_Opnd  \
# 0      17          1        1                  0     16.0        9.0
# 1      11          0        1                  0     11.0       11.0
# 2       8          0        1                  0     12.0       11.0
# 3       4          0        2                  0      8.0        6.0
# 4       7          0        2                  0      7.0        6.0
#
#    total_Op  total_Opnd  branchCount  defects
# 0      38.0        22.0          5.0    False
# 1      18.0        14.0          3.0    False
# 2      28.0        17.0          3.0    False
# 3      16.0         7.0          1.0     True
# 4      10.0        10.0          3.0    False
#
# [5 rows x 23 columns]

# %%
train["defects"] = train["defects"].astype(int)
train = train.drop(["id"], axis=1)

# %%
train["defects"].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Obviously the data is strongly imbalanced. Let's see if there is any blank columns

# %%
train.isnull().sum()
# Out:
# loc                  0
# v(g)                 0
# ev(g)                0
# iv(g)                0
# n                    0
# v                    0
# l                    0
# d                    0
# i                    0
# e                    0
# b                    0
# t                    0
# lOCode               0
# lOComment            0
# lOBlank              0
# locCodeAndComment    0
# uniq_Op              0
# uniq_Opnd            0
# total_Op             0
# total_Opnd           0
# branchCount          0
# defects              0
# dtype: int64

# %%
train
# Out:
#           loc  v(g)  ev(g)  iv(g)      n        v     l      d      i  \
# 0        22.0   3.0    1.0    2.0   60.0   278.63  0.06  19.56  14.25
# 1        14.0   2.0    1.0    2.0   32.0   151.27  0.14   7.00  21.11
# 2        11.0   2.0    1.0    2.0   45.0   197.65  0.11   8.05  22.76
# 3         8.0   1.0    1.0    1.0   23.0    94.01  0.19   5.25  17.86
# 4        11.0   2.0    1.0    2.0   17.0    60.94  0.18   5.63  12.44
# ...       ...   ...    ...    ...    ...      ...   ...    ...    ...
# 101758   10.0   2.0    1.0    1.0   28.0   122.98  0.15   6.60  18.63
# 101759   27.0   5.0    4.0    1.0  107.0   559.93  0.06  18.00  34.17
# 101760   26.0   1.0    1.0    1.0   83.0   360.17  0.04  22.75  12.56
# 101761   10.0   2.0    1.0    2.0   43.0   191.76  0.15   6.46  29.53
# 101762  136.0  18.0   18.0    1.0  296.0  1704.57  0.02  44.82  44.08
#
#                e  ...  lOCode  lOComment  lOBlank  locCodeAndComment  uniq_Op  \
# 0        5448.79  ...      17          1        1                  0     16.0
# 1         936.71  ...      11          0        1                  0     11.0
# 2        1754.01  ...       8          0        1                  0     12.0
# 3         473.66  ...       4          0        2                  0      8.0
# 4         365.67  ...       7          0        2                  0      7.0
# ...          ...  ...     ...        ...      ...                ...      ...
# 101758    811.70  ...       7          0        1                  0     11.0
# 101759  11268.27  ...      23          0        2                  0     18.0
# 101760   5893.69  ...      20          0        4                  0     10.0
# 101761   1534.04  ...       7          0        1                  0     11.0
# 101762  77011.02  ...     102          1       11                  0     22.0
#
#         uniq_Opnd  total_Op  total_Opnd  branchCount  defects
# 0             9.0      38.0        22.0          5.0        0
# 1            11.0      18.0        14.0          3.0        0
# 2            11.0      28.0        17.0          3.0        0
# 3             6.0      16.0         7.0          1.0        1
# 4             6.0      10.0        10.0          3.0        0
# ...           ...       ...         ...          ...      ...
# 101758        8.0      16.0        12.0          3.0        0
# 101759       20.0      67.0        40.0          9.0        0
# 101760        8.0      51.0        28.0          1.0        0
# 101761       14.0      24.0        19.0          3.0        0
# 101762       31.0     162.0       135.0         35.0        0
#
# [101763 rows x 22 columns]

# %%
train.cov()
# Out:
#                             loc           v(g)          ev(g)          iv(g)  \
# loc                2.981204e+03     328.507296     137.704468     210.421645
# v(g)               3.285073e+02      62.423511      26.683911      34.568988
# ev(g)              1.377045e+02      26.683911      21.448584      13.975924
# iv(g)              2.104216e+02      34.568988      13.975924      30.631145
# n                  7.098282e+03     853.299900     309.524495     558.593270
# v                  5.259920e+04    6207.608687    2164.033061    4115.396184
# l                 -2.120625e+00      -0.306270      -0.150887      -0.161559
# d                  4.622120e+02      64.075449      23.395645      38.070184
# i                  6.070546e+02      54.994536      16.999783      40.476870
# e                  5.215968e+06  647718.131508  242869.478553  415868.429144
# b                  1.704262e+01       2.039600       0.705058       1.316708
# t                  2.758412e+05   36786.585051   12807.483696   22633.572799
# lOCode             1.690765e+03     195.443254      68.281171     135.854080
# lOComment          1.701700e+02      17.698578       8.000824      11.032605
# lOBlank            2.337427e+02      23.284709       8.344121      15.048840
# locCodeAndComment  1.343033e+01       1.644139       0.761302       0.987087
# uniq_Op            1.352750e+02      20.793210       6.266169      14.152912
# uniq_Opnd          6.288570e+02      75.979803      23.349591      55.050852
# total_Op           4.364253e+03     527.877303     191.217881     342.278823
# total_Opnd         2.981471e+03     343.513491     123.801360     225.015230
# branchCount        6.002446e+02     110.081470      51.714132      59.656167
# defects            7.832493e+00       0.996263       0.503984       0.569123
#
#                               n             v            l             d  \
# loc                7.098282e+03  5.259920e+04    -2.120625  4.622120e+02
# v(g)               8.532999e+02  6.207609e+03    -0.306270  6.407545e+01
# ev(g)              3.095245e+02  2.164033e+03    -0.150887  2.339565e+01
# iv(g)              5.585933e+02  4.115396e+03    -0.161559  3.807018e+01
# n                  2.929136e+04  2.019177e+05    -5.145332  1.953495e+03
# v                  2.019177e+05  1.614911e+06   -32.320179  1.342522e+04
# l                 -5.145332e+00 -3.232018e+01     0.010019 -6.025811e-01
# d                  1.953495e+03  1.342522e+04    -0.602581  1.994113e+02
# i                  2.837701e+03  1.955926e+04    -0.371320  1.663547e+02
# e                  1.857612e+07  1.410272e+08 -1750.435740  1.268258e+06
# b                  6.629561e+01  5.013725e+02    -0.010735  4.498302e+00
# t                  1.016512e+06  7.400201e+06   -95.761192  6.879881e+04
# lOCode             6.014145e+03  4.404347e+04    -1.117655  4.238921e+02
# lOComment          5.721400e+02  3.990282e+03    -0.111061  4.055962e+01
# lOBlank            8.469270e+02  5.963582e+03    -0.184524  6.095275e+01
# locCodeAndComment  4.494809e+01  3.072682e+02    -0.012546  3.782966e+00
# uniq_Op            7.139176e+02  4.668459e+03    -0.269863  7.460874e+01
# uniq_Opnd          2.532041e+03  1.834094e+04    -0.512874  1.761791e+02
# total_Op           1.723603e+04  1.244027e+05    -3.081259  1.193182e+03
# total_Opnd         1.169424e+04  8.583909e+04    -2.085079  7.944605e+02
# branchCount        1.544180e+03  1.114832e+04    -0.600413  1.170595e+02
# defects            1.849217e+01  1.229946e+02    -0.010612  1.430341e+00
#
#                               i             e  ...        lOCode  \
# loc                6.070546e+02  5.215968e+06  ...  1.690765e+03
# v(g)               5.499454e+01  6.477181e+05  ...  1.954433e+02
# ev(g)              1.699978e+01  2.428695e+05  ...  6.828117e+01
# iv(g)              4.047687e+01  4.158684e+05  ...  1.358541e+02
# n                  2.837701e+03  1.857612e+07  ...  6.014145e+03
# v                  1.955926e+04  1.410272e+08  ...  4.404347e+04
# l                 -3.713196e-01 -1.750436e+03  ... -1.117655e+00
# d                  1.663547e+02  1.268258e+06  ...  4.238921e+02
# i                  5.224307e+02  1.246418e+06  ...  5.964661e+02
# e                  1.246418e+06  3.631746e+10  ...  4.260645e+06
# b                  6.570713e+00  4.943015e+04  ...  1.432744e+01
# t                  6.784097e+04  1.500394e+09  ...  2.254504e+05
# lOCode             5.964661e+02  4.260645e+06  ...  1.485409e+03
# lOComment          5.879753e+01  3.700610e+05  ...  1.263889e+02
# lOBlank            9.545642e+01  5.306403e+05  ...  1.898219e+02
# locCodeAndComment  4.889438e+00  2.371999e+04  ...  1.010306e+01
# uniq_Op            8.140053e+01  3.547842e+05  ...  1.610714e+02
# uniq_Opnd          3.316871e+02  1.428119e+06  ...  5.751464e+02
# total_Op           1.677491e+03  1.153513e+07  ...  3.694231e+03
# total_Opnd         1.212932e+03  7.746453e+06  ...  2.534457e+03
# branchCount        1.034191e+02  1.173126e+06  ...  3.467591e+02
# defects            1.995932e+00  7.608781e+03  ...  4.043673e+00
#
#                        lOComment        lOBlank  locCodeAndComment  \
# loc                   170.170005     233.742687          13.430331
# v(g)                   17.698578      23.284709           1.644139
# ev(g)                   8.000824       8.344121           0.761302
# iv(g)                  11.032605      15.048840           0.987087
# n                     572.140018     846.927037          44.948090
# v                    3990.281876    5963.581860         307.268173
# l                      -0.111061      -0.184524          -0.012546
# d                      40.559617      60.952750           3.782966
# i                      58.797525      95.456421           4.889438
# e                  370060.976706  530640.263844       23719.991771
# b                       1.324153       2.002831           0.103151
# t                   19984.178037   27827.145829        1271.792218
# lOCode                126.388943     189.821881          10.103057
# lOComment              34.838465      21.884886           1.505795
# lOBlank                21.884886      40.734496           1.719658
# locCodeAndComment       1.505795       1.719658           0.997814
# uniq_Op                15.361202      24.137597           1.600422
# uniq_Opnd              51.267868      80.666394           4.539429
# total_Op              344.583510     511.804279          27.079482
# total_Opnd            232.016922     353.481748          18.391996
# branchCount            33.286403      43.760129           3.220526
# defects                 0.507574       0.688905           0.055684
#
#                          uniq_Op     uniq_Opnd      total_Op    total_Opnd  \
# loc                   135.274980  6.288570e+02  4.364253e+03  2.981471e+03
# v(g)                   20.793210  7.597980e+01  5.278773e+02  3.435135e+02
# ev(g)                   6.266169  2.334959e+01  1.912179e+02  1.238014e+02
# iv(g)                  14.152912  5.505085e+01  3.422788e+02  2.250152e+02
# n                     713.917650  2.532041e+03  1.723603e+04  1.169424e+04
# v                    4668.458534  1.834094e+04  1.244027e+05  8.583909e+04
# l                      -0.269863 -5.128736e-01 -3.081259e+00 -2.085079e+00
# d                      74.608739  1.761791e+02  1.193182e+03  7.944605e+02
# i                      81.400527  3.316871e+02  1.677491e+03  1.212932e+03
# e                  354784.169330  1.428119e+06  1.153513e+07  7.746453e+06
# b                       1.534537  6.060198e+00  4.066400e+01  2.828734e+01
# t                   20375.091738  7.911794e+04  6.215915e+05  4.114058e+05
# lOCode                161.071431  5.751464e+02  3.694231e+03  2.534457e+03
# lOComment              15.361202  5.126787e+01  3.445835e+02  2.320169e+02
# lOBlank                24.137597  8.066639e+01  5.118043e+02  3.534817e+02
# locCodeAndComment       1.600422  4.539429e+00  2.707948e+01  1.839200e+01
# uniq_Op                45.556417  8.081487e+01  4.308340e+02  2.853696e+02
# uniq_Opnd              80.814870  3.263175e+02  1.524045e+03  1.082875e+03
# total_Op              430.833997  1.524045e+03  1.092812e+04  7.199455e+03
# total_Opnd            285.369650  1.082875e+03  7.199455e+03  5.139787e+03
# branchCount            35.878206  1.326905e+02  9.491292e+02  6.266962e+02
# defects                 0.504330  1.861308e+00  1.096482e+01  7.586319e+00
#
#                     branchCount      defects
# loc                6.002446e+02     7.832493
# v(g)               1.100815e+02     0.996263
# ev(g)              5.171413e+01     0.503984
# iv(g)              5.965617e+01     0.569123
# n                  1.544180e+03    18.492169
# v                  1.114832e+04   122.994639
# l                 -6.004132e-01    -0.010612
# d                  1.170595e+02     1.430341
# i                  1.034191e+02     1.995932
# e                  1.173126e+06  7608.780583
# b                  3.719758e+00     0.041079
# t                  6.495267e+04   411.234972
# lOCode             3.467591e+02     4.043673
# lOComment          3.328640e+01     0.507574
# lOBlank            4.376013e+01     0.688905
# locCodeAndComment  3.220526e+00     0.055684
# uniq_Op            3.587821e+01     0.504330
# uniq_Opnd          1.326905e+02     1.861308
# total_Op           9.491292e+02    10.964821
# total_Opnd         6.266962e+02     7.586319
# branchCount        2.077279e+02     1.947963
# defects            1.947963e+00     0.175278
#
# [22 rows x 22 columns]

# %% [markdown]
# Next, let's check the distribution of variables.

# %%
sns.heatmap(train.corr())
plt.show()

# %% [markdown]
# And distribution of every variables

# %%
def plot_distribution(df):
    _, axis = plt.subplots(7, 3, figsize=(12, 12))
    
    for col, ax in zip(df.columns, axis.ravel()):
        if df[col].dtype == float:
            ax.hist(df[col], bins=100, color="orange")
        else:
            vc = df[col].value_counts()
            ax.bar(vc.index, vc, color="orange")
        ax.set_xlabel(col)
    
    plt.tight_layout()
    plt.suptitle("Feature distributions", y=1.02, fontsize=20)
    plt.show()

# %%
plot_distribution(train)

# %% [markdown]
# ## Building training pipeline

# %%
transform = FunctionTransformer(np.log1p)

# %%
estimators = [
    ("logistic", LogisticRegression(solver="liblinear", penalty="l2")),
    # ("lasso", LogisticRegression(solver="liblinear", penalty="l1")),
    ("elasticnet", SGDClassifier(loss="log_loss", penalty="elasticnet")),
    # ("svc", SVC(kernel="linear",probability=True)),
]

# %%
X = train.drop(["defects"], axis=1)
y = train["defects"]

# %% [markdown]
# Define pipelines and training

# %%
pipes = {}

for model in estimators:
    print(f"Fitting {model[0]}")
    
    if model[0] in ["svc", "logistic", "lasso"]:
        pipe = Pipeline(steps=[
            ("transform", transform),
            ("poly_features", PolynomialFeatures(2, include_bias=False)),
            ("std_scaler", StandardScaler()),
            model
        ],verbose=True)
        pipe.fit(X, y)
        pipes[pipe.steps[3][0]] = pipe
    else:
        pipe = Pipeline(steps=[
            ("transform", transform),
            model
        ], verbose=True)
        pipe.fit(X, y)
        pipes[pipe.steps[1][0]] = pipe
# Out:
# Fitting logistic
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  40.0s
# Fitting elasticnet
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.7s

# %% [markdown]
# Plotting AUC score for the training

# %%
_metrics = {
    "auc": make_scorer(roc_auc_score, needs_proba=True),
    "log_loss": make_scorer(log_loss)
}

# %%
estimator_names = [model[0] for model in estimators]

# %%
def plot_estimators(estimators=estimator_names, 
                   n_splits=5,
                   metrics=["auc", "log_loss"]):
    metrics = {
        key: _metrics[key] for key in metrics
    }
    
    scorer, labels = [], []
    
    for pipe_name in pipes.keys():
        if pipe_name in estimators:
            pipe = pipes[pipe_name]
            
            print(pipe)
            
            labels.append(pipe_name)
            
            kf = KFold(n_splits)
            
            model_score = cross_validate(pipe, X, y, scoring=metrics, cv=kf)
            
            scorer.append(model_score)
    
    score_lists = {}
    
    for metric in metrics:
        score_lists[metric] = [score[f"test_{metric}"] for score in scorer]
        
    for i, (title, _list) in enumerate(score_lists.items()):
        plt.figure(i)
        plot = sns.boxplot(data=_list).set_xticklabels(labels, rotation=45)
        plt.title(title)

# %%
metrics = {
    "auc": make_scorer(roc_auc_score, needs_proba=True),
    "log_loss": make_scorer(log_loss)
}

# %%
plot_estimators()
# Out:
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('poly_features', PolynomialFeatures(include_bias=False)),
#                 ('std_scaler', StandardScaler()),
#                 ('logistic', LogisticRegression(solver='liblinear'))],
#          verbose=True)
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  25.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  20.2s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  21.9s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  28.4s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  21.3s
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('elasticnet',
#                  SGDClassifier(loss='log_loss', penalty='elasticnet'))],
#          verbose=True)
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.7s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.6s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.7s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.6s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.7s

# %% [markdown]
# ## Hyperparam tuning

# %%
def tune_param(model, param_grid, refit="auc", chart=None, X=X, y=y, cv=5):
    param_grid = {
        f"{model}__{key}" : param_grid[key]
        for key in param_grid.keys()
    }
    
    grid_cv = GridSearchCV(
        pipes[model],
        param_grid,
        scoring=metrics,
        refit=refit,
        return_train_score=True,
        cv=cv,
        verbose=3
    )
    
    grid_cv.fit(X, y)
    
    print(f"Best score: { grid_cv.best_score_ }")
    print(f"Best params: { grid_cv.best_params_ }")
    
    results = pd.DataFrame(grid_cv.cv_results_)
    
    if "line" in chart:
        for i, param in enumerate(param_grid.keys()):
            graph_data = results[[
                f"param_{param}",
                f"mean_test_{refit}",
                f"mean_train_{refit}"
            ]]
            
            graph_data = graph_data.rename(columns = {
                f"mean_test_{refit}" : "test",
                f"mean_train_{refit}" : "train",
            })
            
            graph_data = graph_data.melt(f"param_{param}", var_name="type", value_name=refit)
            plt.figure(i)
            plot = sns.lineplot(x=f"param_{param}", y=refit, hue="type", data=graph_data)
    
    if "heatmap" in chart:
        param1 = list(param_grid.keys())[0]
        param2 = list(param_grid.keys())[1]
        
        graph_data = results[[
            f"param_{param1}",
            f"param_{param2}",
            f"mean_test_{refit}"
        ]]
        
        graph_data = graph_data.pivot(index=f"param_{param1}", 
                                      columns=f"param_{param2}", 
                                     values=f"mean_test_{refit}")
        
        sns.heatmap(graph_data, annot=True, xticklabels=True, yticklabels=True).set(
            xlabel=param2,
            ylabel=param1
        )

# %% [markdown]
# ### Tuning Random Forest

# %%
# pipes['random_forest'].named_steps['random_forest'].get_params()

# %%
# param_grid = {'n_estimators': [100, 200, 300, 400, 500]}
# tune_param('random_forest', param_grid,chart='line')

# %%
# param_grid = {'max_depth': [3,8,13,18]}
# tune_param('random_forest', param_grid,chart='line')

# %%
# param_grid = {'max_leaf_nodes': [5,10,15,20,25]}
# tune_param('random_forest', param_grid,chart='line')

# %% [markdown]
# ### Tuning Logistic Regression

# %%
pipes['logistic'].named_steps['logistic'].get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'liblinear',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000], 
           'tol':[0.001, 0.01, 0.1, 1, 10, 100, 1000]}

tune_param("logistic", param_grid, chart="heatmap")
# Out:
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  20.9s
# [CV 5/5] END logistic__C=1000, logistic__tol=0.001; auc: (train=0.793, test=0.786) log_loss: (train=6.381, test=6.451) total time=  21.3s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   3.6s
# [CV 1/5] END logistic__C=1000, logistic__tol=0.01; auc: (train=0.789, test=0.793) log_loss: (train=6.402, test=6.364) total time=   4.1s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   4.2s
# [CV 2/5] END logistic__C=1000, logistic__tol=0.01; auc: (train=0.791, test=0.786) log_loss: (train=6.388, test=6.428) total time=   4.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   4.1s
# [CV 3/5] END logistic__C=1000, logistic__tol=0.01; auc: (train=0.790, test=0.791) log_loss: (train=6.400, test=6.382) total time=   4.6s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   4.1s
# [CV 4/5] END logistic__C=1000, logistic__tol=0.01; auc: (train=0.790, test=0.790) log_loss: (train=6.369, test=6.496) total time=   4.6s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   2.7s
# [CV 5/5] END logistic__C=1000, logistic__tol=0.01; auc: (train=0.791, test=0.785) log_loss: (train=6.421, test=6.371) total time=   3.1s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   1.6s
# [CV 1/5] END logistic__C=1000, logistic__tol=0.1; auc: (train=0.788, test=0.793) log_loss: (train=6.451, test=6.408) total time=   2.1s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   1.8s
# [CV 2/5] END logistic__C=1000, logistic__tol=0.1; auc: (train=0.790, test=0.784) log_loss: (train=6.442, test=6.442) total time=   2.2s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   1.6s
# [CV 3/5] END logistic__C=1000, logistic__tol=0.1; auc: (train=0.788, test=0.791) log_loss: (train=6.436, test=6.416) total time=   2.1s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   1.7s
# [CV 4/5] END logistic__C=1000, logistic__tol=0.1; auc: (train=0.789, test=0.790) log_loss: (train=6.422, test=6.549) total time=   2.2s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   1.5s
# [CV 5/5] END logistic__C=1000, logistic__tol=0.1; auc: (train=0.789, test=0.784) log_loss: (train=6.441, test=6.440) total time=   2.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.5s
# [CV 1/5] END logistic__C=1000, logistic__tol=1; auc: (train=0.780, test=0.786) log_loss: (train=6.633, test=6.588) total time=   1.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.5s
# [CV 2/5] END logistic__C=1000, logistic__tol=1; auc: (train=0.782, test=0.778) log_loss: (train=6.625, test=6.581) total time=   1.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.5s
# [CV 3/5] END logistic__C=1000, logistic__tol=1; auc: (train=0.780, test=0.782) log_loss: (train=6.611, test=6.720) total time=   1.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.5s
# [CV 4/5] END logistic__C=1000, logistic__tol=1; auc: (train=0.781, test=0.782) log_loss: (train=6.614, test=6.666) total time=   1.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.6s
# [CV 5/5] END logistic__C=1000, logistic__tol=1; auc: (train=0.782, test=0.776) log_loss: (train=6.632, test=6.591) total time=   1.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 1/5] END logistic__C=1000, logistic__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 2/5] END logistic__C=1000, logistic__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 3/5] END logistic__C=1000, logistic__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 4/5] END logistic__C=1000, logistic__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.6s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 5/5] END logistic__C=1000, logistic__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 1/5] END logistic__C=1000, logistic__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 2/5] END logistic__C=1000, logistic__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 3/5] END logistic__C=1000, logistic__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 4/5] END logistic__C=1000, logistic__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 5/5] END logistic__C=1000, logistic__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 1/5] END logistic__C=1000, logistic__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 2/5] END logistic__C=1000, logistic__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 3/5] END logistic__C=1000, logistic__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.3s
# [CV 4/5] END logistic__C=1000, logistic__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   0.2s
# [CV 5/5] END logistic__C=1000, logistic__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.7s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  13.2s
# Best score: 0.7893470471778008
# Best params: {'logistic__C': 0.1, 'logistic__tol': 0.001}
# C:\Users\Acer\AppData\Local\Temp/ipykernel_12620/2445858871.py:51: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   graph_data = graph_data.pivot(index=f"param_{param1}",
# C:\Users\Acer\AppData\Local\Temp/ipykernel_12620/2445858871.py:51: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   graph_data = graph_data.pivot(index=f"param_{param1}",

# %%
pipes["logistic"].set_params(**{
    "logistic__C": 0.1,
    "logistic__tol": .001
})
# Out:
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('poly_features', PolynomialFeatures(include_bias=False)),
#                 ('std_scaler', StandardScaler()),
#                 ('logistic',
#                  LogisticRegression(C=0.1, solver='liblinear', tol=0.001))],
#          verbose=True)

# %% [markdown]
# ### Tuning ElasticNet

# %%
param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000], 
           'tol':[0.001, 0.01, 0.1, 1, 10, 100, 1000]}

tune_param("elasticnet", param_grid, chart="heatmap")
# Out:
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__tol=10; auc: (train=0.352, test=0.357) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__tol=10; auc: (train=0.351, test=0.359) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__tol=10; auc: (train=0.353, test=0.349) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__tol=10; auc: (train=0.354, test=0.348) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__tol=10; auc: (train=0.353, test=0.350) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__tol=100; auc: (train=0.352, test=0.357) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__tol=100; auc: (train=0.351, test=0.359) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__tol=100; auc: (train=0.353, test=0.349) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__tol=100; auc: (train=0.354, test=0.348) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__tol=100; auc: (train=0.353, test=0.350) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__tol=1000; auc: (train=0.352, test=0.357) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__tol=1000; auc: (train=0.351, test=0.359) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__tol=1000; auc: (train=0.353, test=0.349) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__tol=1000; auc: (train=0.353, test=0.347) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__tol=1000; auc: (train=0.353, test=0.350) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.2s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=0.1; auc: (train=0.354, test=0.348) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=100; auc: (train=0.351, test=0.359) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=26.712, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.713) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.713) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=100, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=100, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=100, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=100, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=100, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=26.712, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=0.001; auc: (train=0.500, test=0.500) log_loss: (train=26.712, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=0.01; auc: (train=0.500, test=0.500) log_loss: (train=26.712, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=0.1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=1; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=10; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=100; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 1/5] END elasticnet__alpha=1000, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 2/5] END elasticnet__alpha=1000, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=26.711, test=26.711) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 3/5] END elasticnet__alpha=1000, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.828) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.1s
# [CV 4/5] END elasticnet__alpha=1000, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.827) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [CV 5/5] END elasticnet__alpha=1000, elasticnet__tol=1000; auc: (train=0.500, test=0.500) log_loss: (train=7.828, test=7.829) total time=   0.1s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.3s
# Best score: 0.7834146166669596
# Best params: {'elasticnet__alpha': 0.01, 'elasticnet__tol': 0.001}
# C:\Users\Acer\AppData\Local\Temp/ipykernel_12620/2445858871.py:51: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   graph_data = graph_data.pivot(index=f"param_{param1}",
# C:\Users\Acer\AppData\Local\Temp/ipykernel_12620/2445858871.py:51: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   graph_data = graph_data.pivot(index=f"param_{param1}",

# %%
pipes["elasticnet"].set_params(**{
    "elasticnet__alpha": 0.01,
    "elasticnet__tol": 0.001
})
# Out:
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('elasticnet',
#                  SGDClassifier(alpha=0.01, loss='log_loss',
#                                penalty='elasticnet'))],
#          verbose=True)

# %% [markdown]
# ### Tuning SVC

# %%
# pipes['svc'].named_steps['svc'].get_params()

# %% [markdown]
# ### Post-tuning scores

# %%
plot_estimators(['logistic','elasticnet'])
# Out:
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('poly_features', PolynomialFeatures(include_bias=False)),
#                 ('std_scaler', StandardScaler()),
#                 ('logistic',
#                  LogisticRegression(C=0.1, solver='liblinear', tol=0.001))],
#          verbose=True)
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  11.0s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   8.5s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.2s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   7.1s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=  10.2s
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.1s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] .......... (step 4 of 4) Processing logistic, total=   9.5s
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('elasticnet',
#                  SGDClassifier(alpha=0.01, loss='log_loss',
#                                penalty='elasticnet'))],
#          verbose=True)
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s
# [Pipeline] ......... (step 1 of 2) Processing transform, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing elasticnet, total=   0.2s

# %% [markdown]
# ## Ensemble

# %% [markdown]
# ### Learning curves

# %%
from sklearn.model_selection import learning_curve

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
dummy_transform = transform
X_dummy = dummy_transform.fit_transform(X)

# %%
to_plot = ["logistic", "elasticnet"]

for name in pipes.keys():
    if name in to_plot:
        g = plot_learning_curve(
            pipes[name].named_steps[name],
            f"{name} learning curves",
            X_dummy,
            y,
            cv=KFold(5),
            n_jobs=4
        )

# %% [markdown]
# ### Tree-based feature importance (todo)

# %%
# TODO

# %% [markdown]
# ### Estimator prediction correlation

# %%
ensemble_results = pd.DataFrame()

for name, pipe in pipes.items():
    ensemble_results[name] = pipe.predict(X)
    
sns.heatmap(ensemble_results.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Predicting the test set

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.base import clone

# %%
for pipe in pipes.values():
    print(pipe.steps[1])
# Out:
# ('poly_features', PolynomialFeatures(include_bias=False))
# ('elasticnet', SGDClassifier(alpha=0.01, loss='log_loss', penalty='elasticnet'))

# %%
pipes
# Out:
# {'logistic': Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                  ('poly_features', PolynomialFeatures(include_bias=False)),
#                  ('std_scaler', StandardScaler()),
#                  ('logistic',
#                   LogisticRegression(C=0.1, solver='liblinear', tol=0.001))],
#           verbose=True),
#  'elasticnet': Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                  ('elasticnet',
#                   SGDClassifier(alpha=0.01, loss='log_loss',
#                                 penalty='elasticnet'))],
#           verbose=True)}

# %%
voting_estimators = [
    (pipes["logistic"].steps[3][0], clone(pipes["logistic"].steps[3][1])),
    (pipes["elasticnet"].steps[1][0], clone(pipes["elasticnet"].steps[1][1]))
]

# %%
vote = Pipeline([
    ("transform", transform),
    ("poly_features", PolynomialFeatures(2, include_bias=False)),
    ("std_scaler", StandardScaler()),
    ("voter", VotingClassifier(voting_estimators, voting="soft"))
], verbose=True)

# %%
vote.fit(X, y)
# Out:
# [Pipeline] ......... (step 1 of 4) Processing transform, total=   0.0s
# [Pipeline] ..... (step 2 of 4) Processing poly_features, total=   0.2s
# [Pipeline] ........ (step 3 of 4) Processing std_scaler, total=   0.3s
# [Pipeline] ............. (step 4 of 4) Processing voter, total=  14.1s
# Pipeline(steps=[('transform', FunctionTransformer(func=<ufunc 'log1p'>)),
#                 ('poly_features', PolynomialFeatures(include_bias=False)),
#                 ('std_scaler', StandardScaler()),
#                 ('voter',
#                  VotingClassifier(estimators=[('logistic',
#                                                LogisticRegression(C=0.1,
#                                                                   solver='liblinear',
#                                                                   tol=0.001)),
#                                               ('elasticnet',
#                                                SGDClassifier(alpha=0.01,
#                                                              loss='log_loss',
#                                                              penalty='elasticnet'))],
#                                   voting='soft'))],
#          verbose=True)

# %%
test_data = test.drop(["id"], axis=1)

# %%
pred_probs = vote.predict_proba(test_data)[:, 1]

# %%
pred_probs
# Out:
# array([0.24016709, 0.17884894, 0.69392954, ..., 0.17934975, 0.09898075,
#        0.62485007])

# %%
plt.hist(pred_probs)
plt.show()

# %%
submission_df = pd.DataFrame({
    "id": test["id"],
    "defects": pred_probs
})

# %%
submission_df.to_csv("submission.csv", index=False)
